# %%
# !apt install cmake libboost-all-dev libsdl2-dev libfreetype6-dev libgl1-mesa-dev libglu1-mesa-dev libpng-dev libjpeg-dev libbz2-dev libfluidsynth-dev libgme-dev libopenal-dev zlib1g-dev timidity tar nasm
# !pip install vizdoom==1.1.9
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libglu1-mesa-dev is already the newest version (9.0.0-2.1build1).
# libglu1-mesa-dev set to manually installed.
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# libbz2-dev is already the newest version (1.0.6-8.1ubuntu0.2).
# libbz2-dev set to manually installed.
# libfreetype6-dev is already the newest version (2.8.1-2ubuntu2.1).
# libgl1-mesa-dev is already the newest version (20.0.8-0ubuntu1~18.04.1).
# libgl1-mesa-dev set to manually installed.
# libpng-dev is already the newest version (1.6.34-1ubuntu0.18.04.2).
# The following additional packages will be installed:
#   freepats gir1.2-ibus-1.0 libaudio2 libcapnp-0.6.1 libdbus-1-dev
#   libfluidsynth1 libibus-1.0-5 libibus-1.0-dev libmirclient-dev libmirclient9
#   libmircommon-dev libmircommon7 libmircookie-dev libmircookie2 libmircore-dev
#   libmircore1 libmirprotobuf3 libprotobuf-dev libprotobuf-lite10 libpulse-dev
#   libpulse-mainloop-glib0 libsndio-dev libudev-dev libxcursor-dev
#   libxinerama-dev libxkbcommon-dev libxrandr-dev libxv-dev timidity-daemon
#   x11proto-randr-dev x11proto-xinerama-dev
# Suggested packages:
#   nas fluidr3mono-gm-soundfont | timgm6mb-soundfont | fluid-soundfont-gm
#   ncompress tar-scripts tar-doc fluid-soundfont-gm fluid-soundfont-gs pmidi
# The following NEW packages will be installed:
#   freepats gir1.2-ibus-1.0 libaudio2 libcapnp-0.6.1 libdbus-1-dev
#   libfluidsynth-dev libfluidsynth1 libgme-dev libibus-1.0-5 libibus-1.0-dev
#   libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libopenal-dev libprotobuf-dev libprotobuf-lite10 libpulse-dev
#   libpulse-mainloop-glib0 libsdl2-dev libsndio-dev libudev-dev libxcursor-dev
#   libxinerama-dev libxkbcommon-dev libxrandr-dev libxv-dev nasm timidity
#   timidity-daemon x11proto-randr-dev x11proto-xinerama-dev
# The following packages will be upgraded:
#   tar
# 1 upgraded, 37 newly installed, 0 to remove and 36 not upgraded.
# Need to get 34.2 MB of archives.
# After this operation, 63.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 tar amd64 1.29b-2ubuntu0.2 [234 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freepats all 20060219-1 [29.0 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-5 amd64 1.5.17-3ubuntu5.3 [133 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-ibus-1.0 amd64 1.5.17-3ubuntu5.3 [66.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaudio2 amd64 1.9.4-6 [50.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcapnp-0.6.1 amd64 0.6.1-1ubuntu1 [658 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdbus-1-dev amd64 1.12.2-1ubuntu1.2 [165 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth1 amd64 1.1.9-1 [137 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth-dev amd64 1.1.9-1 [19.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgme-dev amd64 0.6.2-1 [5,796 B]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-dev amd64 1.5.17-3ubuntu5.3 [145 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore1 amd64 0.31.1-0ubuntu1 [26.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon7 amd64 0.31.1-0ubuntu1 [73.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirprotobuf3 amd64 0.31.1-0ubuntu1 [127 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient9 amd64 0.31.1-0ubuntu1 [199 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore-dev amd64 0.31.1-0ubuntu1 [21.7 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon-dev amd64 0.8.2-1~ubuntu18.04.1 [150 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon-dev amd64 0.31.1-0ubuntu1 [13.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie2 amd64 0.31.1-0ubuntu1 [19.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie-dev amd64 0.31.1-0ubuntu1 [4,392 B]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient-dev amd64 0.31.1-0ubuntu1 [47.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal-dev amd64 1:1.18.2-2 [20.9 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-mainloop-glib0 amd64 1:11.1-1ubuntu7.11 [22.1 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-dev amd64 1:11.1-1ubuntu7.11 [81.5 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio-dev amd64 1.1.0-3 [13.3 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev-dev amd64 237-3ubuntu10.52 [19.1 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-dev amd64 2.0.8+dfsg1-1ubuntu1.18.04.4 [683 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/universe amd64 nasm amd64 2.13.02-0.1 [359 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/universe amd64 timidity amd64 2.13.2-41 [585 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/universe amd64 timidity-daemon all 2.13.2-41 [5,984 B]
# Fetched 34.2 MB in 1s (59.3 MB/s)
# Extracting templates from packages: 100%
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../tar_1.29b-2ubuntu0.2_amd64.deb ...
# Unpacking tar (1.29b-2ubuntu0.2) over (1.29b-2ubuntu0.1) ...
# Setting up tar (1.29b-2ubuntu0.2) ...
# update-alternatives: warning: forcing reinstallation of alternative /usr/sbin/rmt-tar because link group rmt is broken
# Selecting previously unselected package freepats.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../00-freepats_20060219-1_all.deb ...
# Unpacking freepats (20060219-1) ...
# Selecting previously unselected package libibus-1.0-5:amd64.
# Preparing to unpack .../01-libibus-1.0-5_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../02-gir1.2-ibus-1.0_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libaudio2:amd64.
# Preparing to unpack .../03-libaudio2_1.9.4-6_amd64.deb ...
# Unpacking libaudio2:amd64 (1.9.4-6) ...
# Selecting previously unselected package libcapnp-0.6.1:amd64.
# Preparing to unpack .../04-libcapnp-0.6.1_0.6.1-1ubuntu1_amd64.deb ...
# Unpacking libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../05-libdbus-1-dev_1.12.2-1ubuntu1.2_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.2-1ubuntu1.2) ...
# Selecting previously unselected package libfluidsynth1:amd64.
# Preparing to unpack .../06-libfluidsynth1_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth1:amd64 (1.1.9-1) ...
# Selecting previously unselected package libfluidsynth-dev:amd64.
# Preparing to unpack .../07-libfluidsynth-dev_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth-dev:amd64 (1.1.9-1) ...
# Selecting previously unselected package libgme-dev:amd64.
# Preparing to unpack .../08-libgme-dev_0.6.2-1_amd64.deb ...
# Unpacking libgme-dev:amd64 (0.6.2-1) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../09-libibus-1.0-dev_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libmircore1:amd64.
# Preparing to unpack .../10-libmircore1_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircommon7:amd64.
# Preparing to unpack .../11-libmircommon7_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../12-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libmirprotobuf3:amd64.
# Preparing to unpack .../13-libmirprotobuf3_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient9:amd64.
# Preparing to unpack .../14-libmirclient9_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircore-dev:amd64.
# Preparing to unpack .../15-libmircore-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../16-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../17-libxkbcommon-dev_0.8.2-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Selecting previously unselected package libmircommon-dev:amd64.
# Preparing to unpack .../18-libmircommon-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie2:amd64.
# Preparing to unpack .../19-libmircookie2_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie-dev:amd64.
# Preparing to unpack .../20-libmircookie-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient-dev:amd64.
# Preparing to unpack .../21-libmirclient-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libopenal-dev:amd64.
# Preparing to unpack .../22-libopenal-dev_1%3a1.18.2-2_amd64.deb ...
# Unpacking libopenal-dev:amd64 (1:1.18.2-2) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../23-libpulse-mainloop-glib0_1%3a11.1-1ubuntu7.11_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.11) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../24-libpulse-dev_1%3a11.1-1ubuntu7.11_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:11.1-1ubuntu7.11) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../25-libsndio-dev_1.1.0-3_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.1.0-3) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../26-libudev-dev_237-3ubuntu10.52_amd64.deb ...
# Unpacking libudev-dev:amd64 (237-3ubuntu10.52) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../27-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../28-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../29-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../30-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../31-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../32-libxv-dev_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../33-libsdl2-dev_2.0.8+dfsg1-1ubuntu1.18.04.4_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Selecting previously unselected package nasm.
# Preparing to unpack .../34-nasm_2.13.02-0.1_amd64.deb ...
# Unpacking nasm (2.13.02-0.1) ...
# Selecting previously unselected package timidity.
# Preparing to unpack .../35-timidity_2.13.2-41_amd64.deb ...
# Unpacking timidity (2.13.2-41) ...
# Selecting previously unselected package timidity-daemon.
# Preparing to unpack .../36-timidity-daemon_2.13.2-41_all.deb ...
# Unpacking timidity-daemon (2.13.2-41) ...
# Setting up libdbus-1-dev:amd64 (1.12.2-1ubuntu1.2) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.11) ...
# Setting up libpulse-dev:amd64 (1:11.1-1ubuntu7.11) ...
# Setting up libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libgme-dev:amd64 (0.6.2-1) ...
# Setting up libsndio-dev:amd64 (1.1.0-3) ...
# Setting up libopenal-dev:amd64 (1:1.18.2-2) ...
# Setting up libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up nasm (2.13.02-0.1) ...
# Setting up libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Setting up libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Setting up freepats (20060219-1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libudev-dev:amd64 (237-3ubuntu10.52) ...
# Setting up libfluidsynth1:amd64 (1.1.9-1) ...
# Setting up libaudio2:amd64 (1.9.4-6) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Setting up libfluidsynth-dev:amd64 (1.1.9-1) ...
# Setting up timidity (2.13.2-41) ...
# Setting up libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Setting up libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up timidity-daemon (2.13.2-41) ...
# Adding group timidity....done
# Adding system user timidity....done
# Adding user `timidity' to group `audio' ...
# Adding user timidity to group audio
# Done.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for systemd (237-3ubuntu10.52) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Collecting vizdoom==1.1.9
#   Downloading vizdoom-1.1.9.tar.gz (15.0 MB)
#      |████████████████████████████████| 15.0 MB 15.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from vizdoom==1.1.9) (1.19.5)
# Building wheels for collected packages: vizdoom
#   Building wheel for vizdoom (PEP 517) ... done
#   Created wheel for vizdoom: filename=vizdoom-1.1.9-py3-none-any.whl size=14082056 sha256=443e59c64ca90f6eb34c1a97e85c326af07180a4b00fce0e1a5e6f8b0ddb1b6f
#   Stored in directory: /root/.cache/pip/wheels/89/75/34/2c03a5cc9d572ad08bed39e67bf0da279f63b03864a3aa2c66
# Successfully built vizdoom
# Installing collected packages: vizdoom
# Successfully installed vizdoom-1.1.9

# %%
import vizdoom as vzd
from vizdoom import Mode
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
import itertools as it
import skimage.transform
from time import sleep, time
from collections import deque
from tqdm import trange

import PIL
import numpy as np
import os

import json
import zipfile
import os.path

from torchvision import models
import torchvision.transforms as T
from PIL import Image

# %%
KAGGLE_DIR = '/root/.kaggle'
KAGGLE_JSON = '/root/.kaggle/kaggle.json'

# !rm -rf $KAGGLE_DIR
# !mkdir $KAGGLE_DIR
# !touch $KAGGLE_JSON

# for further information check:
# 1) https://stackoverflow.com/questions/56816537/cant-find-kaggle-json-file-in-google-colab
# 2) https://github.com/Kaggle/kaggle-api#api-credentials
api_token = {"username":"alejandromp12","key":"3e66a7513e5ca8e651ba775382b06f3b"}

with open(KAGGLE_JSON, 'w') as file:
    json.dump(api_token, file)

# !chmod 600 $KAGGLE_JSON

# directory that contains vizdoom
directory_vizdoom = '/content/ViZDoom-master/ViZDoom-master'
if os.path.exists(directory_vizdoom):
  print("VIZDoom already downloaded!")
else:
  # !kaggle datasets download --unzip -p /content/ alejandromp12/myweightsganstask
# Out:
# Downloading myweightsganstask.zip to /content
#  88% 5.00M/5.71M [00:00<00:00, 27.1MB/s]
# 100% 5.71M/5.71M [00:00<00:00, 28.0MB/s]

# %%
# Q-learning settings
learning_rate = 0.00025
discount_factor = 0.99
train_epochs = 10 #5
learning_steps_per_epoch = 2000
replay_memory_size = 10000

# NN learning settings
batch_size = 64

# Training regime
test_episodes_per_epoch = 100

# Other parameters
frame_repeat = 12
resolution = (30, 45)
episodes_to_watch = 10

model_savefile = "/content/model-doom-prepossed.pth"
model_savefile_base = "/content/model-doom-base.pth"
save_model = True
load_model = False
skip_learning = False

# Uses GPU if available
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
    torch.backends.cudnn.benchmark = True
else:
    DEVICE = torch.device('cpu')

# %%
class DuelQNet(nn.Module):
    """
    This is Duel DQN architecture.
    see https://arxiv.org/abs/1511.06581 for more information.
    """

    def __init__(self, available_actions_count):
        super(DuelQNet, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=3, stride=2, bias=False),
            nn.BatchNorm2d(8),
            nn.ReLU()
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(8, 8, kernel_size=3, stride=2, bias=False),
            nn.BatchNorm2d(8),
            nn.ReLU()
        )

        self.conv3 = nn.Sequential(
            nn.Conv2d(8, 8, kernel_size=3, stride=1, bias=False),
            nn.BatchNorm2d(8),
            nn.ReLU()
        )

        self.conv4 = nn.Sequential(
            nn.Conv2d(8, 16, kernel_size=3, stride=1, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU()
        )

        self.state_fc = nn.Sequential(
            nn.Linear(96, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

        self.advantage_fc = nn.Sequential(
            nn.Linear(96, 64),
            nn.ReLU(),
            nn.Linear(64, available_actions_count)
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.view(-1, 192)
        x1 = x[:, :96]  # input for the net to calculate the state value
        x2 = x[:, 96:]  # relative advantage of actions in the state
        state_value = self.state_fc(x1).reshape(-1, 1)
        advantage_values = self.advantage_fc(x2)
        x = state_value + (advantage_values - advantage_values.mean(dim=1).reshape(-1, 1))

        return x

class DQNAgent:
    def __init__(self, action_size, memory_size, batch_size, discount_factor, 
                 lr, load_model, model_file, epsilon=1, epsilon_decay=0.9996, epsilon_min=0.1):
        self.action_size = action_size
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.batch_size = batch_size
        self.discount = discount_factor
        self.lr = lr
        self.memory = deque(maxlen=memory_size)
        self.criterion = nn.MSELoss()

        if load_model:
            print("Loading model from: ", model_file)
            self.q_net = torch.load(model_file)
            self.target_net = torch.load(model_file)
            self.epsilon = self.epsilon_min

        else:
            print("Initializing new model")
            self.q_net = DuelQNet(action_size).to(DEVICE)
            self.target_net = DuelQNet(action_size).to(DEVICE)

        self.opt = optim.SGD(self.q_net.parameters(), lr=self.lr)

    def get_action(self, state):
        if np.random.uniform() < self.epsilon:
            return random.choice(range(self.action_size))
        else:
            state = np.expand_dims(state, axis=0)
            state = torch.from_numpy(state).float().to(DEVICE)
            action = torch.argmax(self.q_net(state)).item()
            return action

    def update_target_net(self):
        self.target_net.load_state_dict(self.q_net.state_dict())

    def append_memory(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def train(self):
        batch = random.sample(self.memory, self.batch_size)
        batch = np.array(batch, dtype=object)

        states = np.stack(batch[:, 0]).astype(float)
        actions = batch[:, 1].astype(int)
        rewards = batch[:, 2].astype(float)
        next_states = np.stack(batch[:, 3]).astype(float)
        dones = batch[:, 4].astype(bool)
        not_dones = ~dones

        row_idx = np.arange(self.batch_size)  # used for indexing the batch

        # value of the next states with double q learning
        # see https://arxiv.org/abs/1509.06461 for more information on double q learning
        with torch.no_grad():
            next_states = torch.from_numpy(next_states).float().to(DEVICE)
            idx = row_idx, np.argmax(self.q_net(next_states).cpu().data.numpy(), 1)
            next_state_values = self.target_net(next_states).cpu().data.numpy()[idx]
            next_state_values = next_state_values[not_dones]

        # this defines y = r + discount * max_a q(s', a)
        q_targets = rewards.copy()
        q_targets[not_dones] += self.discount * next_state_values
        q_targets = torch.from_numpy(q_targets).float().to(DEVICE)

        # this selects only the q values of the actions taken
        idx = row_idx, actions
        states = torch.from_numpy(states).float().to(DEVICE)
        action_values = self.q_net(states)[idx].float().to(DEVICE)

        self.opt.zero_grad()
        td_error = self.criterion(q_targets, action_values)
        td_error.backward()
        self.opt.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        else:
            self.epsilon = self.epsilon_min

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import skimage.io
import skimage.color
import skimage.filters

def capture_just_actor_and_enemy(img):
  # blur the image to denoise
  blurred_image = skimage.filters.gaussian(img, sigma=1.0)
  if blurred_image.min() == blurred_image.max():
    #print("The input image seems to have just one color")
    return blurred_image
  # perform automatic thresholding to produce a binary image
  t = skimage.filters.threshold_otsu(blurred_image)
  binary_mask = blurred_image > t
  return binary_mask

def reduce_resolution(img):
    """Down samples image to resolution"""
    img = skimage.transform.resize(img, resolution)
    img = img.astype(np.float32)
    img = np.expand_dims(img, axis=0)
    return img

def preprocess(img):
    img = capture_just_actor_and_enemy(img)
    img = reduce_resolution(img)
    return img

def create_simple_game(config_file_path, train_mode = False):
    print("Initializing doom...")
    game = vzd.DoomGame()
    game.load_config(config_file_path)
    game.set_window_visible(False)
    game.set_mode(Mode.PLAYER)
    game.set_screen_format(vzd.ScreenFormat.GRAY8)
    game.set_screen_resolution(vzd.ScreenResolution.RES_640X480)
    if train_mode is True:
      # Enables depth buffer.
      game.set_depth_buffer_enabled(True)
      # Enables labeling of in game objects labeling.
      game.set_labels_buffer_enabled(True)
    game.init()
    print("Doom initialized.")

    return game

def test(game, agent, actions):
    """Runs a test_episodes_per_epoch episodes and prints the result"""
    print("\nTesting...")
    test_scores = []
    for test_episode in trange(test_episodes_per_epoch, leave=False):
        game.new_episode()
        while not game.is_episode_finished():
            state = preprocess(game.get_state().screen_buffer)
            best_action_index = agent.get_action(state)

            game.make_action(actions[best_action_index], frame_repeat)
        r = game.get_total_reward()
        test_scores.append(r)

    test_scores = np.array(test_scores)
    print("Results: mean: %.1f +/- %.1f," % (
        test_scores.mean(), test_scores.std()), "min: %.1f" % test_scores.min(),
          "max: %.1f" % test_scores.max())


def run(game, agent, actions, num_epochs, frame_repeat, steps_per_epoch=2000):
    """
    Run num epochs of training episodes.
    Skip frame_repeat number of frames after each action.
    """

    start_time = time()

    for epoch in range(num_epochs):
        game.new_episode()
        train_scores = []
        global_step = 0
        print("\nEpoch #" + str(epoch + 1))

        for _ in trange(steps_per_epoch, leave=False):
            state = preprocess(game.get_state().labels_buffer)
            action = agent.get_action(state)
            reward = game.make_action(actions[action], frame_repeat)
            done = game.is_episode_finished()

            if not done:
                next_state = preprocess(game.get_state().labels_buffer)
            else:
                next_state = np.zeros((1, 30, 45)).astype(np.float32)

            agent.append_memory(state, action, reward, next_state, done)

            if global_step > agent.batch_size:
                agent.train()

            if done:
                train_scores.append(game.get_total_reward())
                game.new_episode()

            global_step += 1

        agent.update_target_net()
        train_scores = np.array(train_scores)

        print("Results: mean: %.1f +/- %.1f," % (train_scores.mean(), train_scores.std()),
              "min: %.1f," % train_scores.min(), "max: %.1f," % train_scores.max())

        test(game, agent, actions)
        if save_model:
            print("Saving the network weights to:", model_savefile)
            torch.save(agent.q_net, model_savefile)
        print("Total elapsed time: %.2f minutes" % ((time() - start_time) / 60.0))

    game.close()
    return agent, game

# %%
# Initialize game and actions
doom_game = None
doom_agent = None
doom_actions = []

# %%
def train_agent(agent, game):
    n = game.get_available_buttons_size()
    doom_actions = [list(a) for a in it.product([0, 1], repeat=n)]
  
    agent = DQNAgent(len(doom_actions), lr=learning_rate, batch_size=batch_size,
                     memory_size=replay_memory_size, discount_factor=discount_factor,
                     load_model = os.path.isfile(model_savefile), model_file = model_savefile)

    # Run the training for the set number of epochs
    if not skip_learning:
        agent, game = run(game, agent, doom_actions, num_epochs=train_epochs, frame_repeat=frame_repeat,
                          steps_per_epoch=learning_steps_per_epoch)

        print("======================================")
        print("Training finished. It's time to watch!")
    return agent, game

# %%
train_the_model = False

if __name__ == '__main__' and train_the_model is True:
  # Configuration file path
  #config_file_path = directory_vizdoom + "/scenarios/simpler_basic.cfg"
  # config_file_path = directory_vizdoom + "/scenarios/rocket_basic.cfg"
  config_file_paths = [directory_vizdoom + "/scenarios/basic.cfg",
                      directory_vizdoom + "/scenarios/defend_the_center.cfg",
                      directory_vizdoom + "/scenarios/health_gathering.cfg",
                      directory_vizdoom + "/scenarios/defend_the_line.cfg"
                      ]

  for idx , conf_file  in enumerate(config_file_paths):
    doom_game = create_simple_game(conf_file, train_mode = True)
    doom_agent, doom_game = train_agent(doom_agent, doom_game)
    doom_game.close()

# %%
use_loaded_model = True
#conf_file = directory_vizdoom + "/scenarios/basic.cfg"
#conf_file = directory_vizdoom + "/scenarios/defend_the_line.cfg"
#conf_file = directory_vizdoom + "/scenarios/deathmatch.cfg"
conf_file = directory_vizdoom + "/scenarios/defend_the_center.cfg"
model_to_test = model_savefile
#model_to_test = model_savefile_base
if use_loaded_model and os.path.isfile(model_to_test):
  doom_game = create_simple_game(conf_file)
  n = doom_game.get_available_buttons_size()
  doom_actions = [list(a) for a in it.product([0, 1], repeat=n)]
  doom_agent = DQNAgent(len(doom_actions), lr=learning_rate, batch_size=batch_size,
                   memory_size=replay_memory_size, discount_factor=discount_factor,
                   load_model = True, model_file = model_to_test)
# Out:
# Initializing doom...
# Doom initialized.
# Loading model from:  /content/model-doom-prepossed.pth

# %%
# Reinitialize the game
episodes_images = []

doom_game.close()
doom_game.set_mode(Mode.ASYNC_PLAYER)
if conf_file == directory_vizdoom + "/scenarios/basic.cfg":
  doom_game.set_episode_timeout(6000)
#doom_game.set_doom_skill(5) # very easy just to test
doom_game.set_render_all_frames(True)
doom_game.init()
for _ in range(episodes_to_watch):
    doom_game.new_episode()
    img_frames = []
    while not doom_game.is_episode_finished():
        image_buffer = doom_game.get_state().screen_buffer
        img_frames.append(image_buffer)
        state = preprocess(image_buffer)
        best_action_index = doom_agent.get_action(state)
        # Instead of make_action(a, frame_repeat) in order to make the animation smooth
        doom_game.set_action(doom_actions[best_action_index])
        for _ in range(frame_repeat):
            doom_game.advance_action()
    # Sleep between episodes
    sleep(1.0)
    score = doom_game.get_total_reward()
    episodes_images.append(img_frames)
    print("Total score: ", score)
# Out:
# Total score:  -1.0
# Total score:  2.0
# Total score:  1.0
# Total score:  1.0
# Total score:  0.0
# Total score:  1.0
# Total score:  0.0
# Total score:  0.0
# Total score:  0.0
# Total score:  2.0

# %%
doom_data_path = '/content/doom_data'
# !rm -rf $doom_data_path
# !mkdir -p $doom_data_path
for data_index , frames  in enumerate(episodes_images):
  episode_dir = '{0}/episode_{1}'.format(doom_data_path, str(data_index))
  # !mkdir -p $episode_dir
  for idx , image in enumerate(frames):
    PIL.Image.fromarray(image).save('{}/{}.png'.format(episode_dir, idx))

# %%
doom_videos_path = '/content/doom_videos'
# !rm -rf $doom_videos_path
# !mkdir -p $doom_videos_path
episode_names = [item for item in os.listdir(doom_data_path)]

episodes_dirs = []
for dir in os.listdir(doom_data_path):
  episodes_dirs.append(doom_data_path + '/' + dir)

for idx , dir  in enumerate(episodes_dirs, start=0):
  episode = doom_videos_path + '/' + episode_names[idx] + '.mp4'
  frames = f'{dir}/%01d.png'
  # !ffmpeg -r 1/0.7 -start_number 0 -i $frames -c:v libx264 -vf fps=25 -pix_fmt yuv420p $episode
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/doom_data/episode_3/%01d.png':
#   Duration: 00:00:00.88, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, gray(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x557356be1e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x557356be1e00] profile High, level 3.0
# [libx264 @ 0x557356be1e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/doom_videos/episode_3.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  385 fps=128 q=-1.0 Lsize=     636kB time=00:00:15.28 bitrate= 341.1kbits/s speed=5.07x
# video:631kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.843723%
# [libx264 @ 0x557356be1e00] frame I:2     Avg QP:16.97  size: 68663
# [libx264 @ 0x557356be1e00] frame P:97    Avg QP:15.19  size:  5153
# [libx264 @ 0x557356be1e00] frame B:286   Avg QP:20.39  size:    29
# [libx264 @ 0x557356be1e00] consecutive B-frames:  0.8%  0.5%  0.0% 98.7%
# [libx264 @ 0x557356be1e00] mb I  I16..4: 12.4% 30.9% 56.8%
# [libx264 @ 0x557356be1e00] mb P  I16..4:  0.2%  1.0%  2.6%  P16..4:  6.5%  2.3%  1.8%  0.0%  0.0%    skip:85.6%
# [libx264 @ 0x557356be1e00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.9%  0.0%  0.0%  direct: 0.0%  skip:99.1%  L0:32.3% L1:67.4% BI: 0.3%
# [libx264 @ 0x557356be1e00] 8x8 transform intra:27.5% inter:38.2%
# [libx264 @ 0x557356be1e00] coded y,uvDC,uvAC intra: 95.2% 0.0% 0.0% inter: 1.8% 0.0% 0.0%
# [libx264 @ 0x557356be1e00] i16 v,h,dc,p: 17% 31% 45%  8%
# [libx264 @ 0x557356be1e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 18% 40%  5%  5%  7%  6%  5%  8%
# [libx264 @ 0x557356be1e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 26% 19%  6%  7%  5%  9%  5%  9%
# [libx264 @ 0x557356be1e00] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x557356be1e00] Weighted P-Frames: Y:3.1% UV:0.0%
# [libx264 @ 0x557356be1e00] ref P L0: 62.5% 19.7% 17.0%  0.9%
# [libx264 @ 0x557356be1e00] ref B L0: 89.0% 10.4%  0.6%
# [libx264 @ 0x557356be1e00] ref B L1: 92.5%  7.5%
# [libx264 @ 0x557356be1e00] kb/s:335.26
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/doom_data/episode_2/%01d.png':
#   Duration: 00:00:01.12, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, gray(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5609e4d87e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5609e4d87e00] profile High, level 3.0
# [libx264 @ 0x5609e4d87e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/doom_videos/episode_2.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  490 fps=131 q=-1.0 Lsize=     674kB time=00:00:19.48 bitrate= 283.3kbits/s speed=5.19x
# video:667kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.981245%
# [libx264 @ 0x5609e4d87e00] frame I:2     Avg QP:17.02  size: 70316
# [libx264 @ 0x5609e4d87e00] frame P:123   Avg QP:15.93  size:  4318
# [libx264 @ 0x5609e4d87e00] frame B:365   Avg QP:21.74  size:    29
# [libx264 @ 0x5609e4d87e00] consecutive B-frames:  0.6%  0.0%  0.6% 98.8%
# [libx264 @ 0x5609e4d87e00] mb I  I16..4: 10.2% 30.9% 58.9%
# [libx264 @ 0x5609e4d87e00] mb P  I16..4:  0.2%  1.0%  2.3%  P16..4:  6.2%  1.8%  1.4%  0.0%  0.0%    skip:87.0%
# [libx264 @ 0x5609e4d87e00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.0%  0.0%  0.0%  direct: 0.0%  skip:99.0%  L0:26.3% L1:73.3% BI: 0.4%
# [libx264 @ 0x5609e4d87e00] 8x8 transform intra:29.2% inter:44.5%
# [libx264 @ 0x5609e4d87e00] coded y,uvDC,uvAC intra: 94.0% 0.0% 0.0% inter: 1.6% 0.0% 0.0%
# [libx264 @ 0x5609e4d87e00] i16 v,h,dc,p: 25% 25% 42%  8%
# [libx264 @ 0x5609e4d87e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6% 16% 39%  5%  7%  7%  6%  5%  8%
# [libx264 @ 0x5609e4d87e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 24% 19%  6%  7%  5%  9%  5%  8%
# [libx264 @ 0x5609e4d87e00] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x5609e4d87e00] Weighted P-Frames: Y:1.6% UV:0.0%
# [libx264 @ 0x5609e4d87e00] ref P L0: 65.7% 15.1% 17.7%  1.5%
# [libx264 @ 0x5609e4d87e00] ref B L0: 89.7%  9.8%  0.4%
# [libx264 @ 0x5609e4d87e00] ref B L1: 89.6% 10.4%
# [libx264 @ 0x5609e4d87e00] kb/s:278.54
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/doom_data/episode_9/%01d.png':
#   Duration: 00:00:01.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, gray(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x556f4158de00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x556f4158de00] profile High, level 3.0
# [libx264 @ 0x556f4158de00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/doom_videos/episode_9.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  525 fps=124 q=-1.0 Lsize=    1088kB time=00:00:20.88 bitrate= 427.0kbits/s speed=4.92x
# video:1081kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.645119%
# [libx264 @ 0x556f4158de00] frame I:3     Avg QP:16.93  size: 73684
# [libx264 @ 0x556f4158de00] frame P:132   Avg QP:16.58  size:  6617
# [libx264 @ 0x556f4158de00] frame B:390   Avg QP:20.75  size:    31
# [libx264 @ 0x556f4158de00] consecutive B-frames:  1.0%  0.0%  0.0% 99.0%
# [libx264 @ 0x556f4158de00] mb I  I16..4:  9.0% 23.4% 67.6%
# [libx264 @ 0x556f4158de00] mb P  I16..4:  0.2%  1.0%  2.7%  P16..4:  6.9%  3.4%  2.6%  0.0%  0.0%    skip:83.1%
# [libx264 @ 0x556f4158de00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.1%  0.0%  0.0%  direct: 0.0%  skip:98.9%  L0:29.5% L1:70.3% BI: 0.3%
# [libx264 @ 0x556f4158de00] 8x8 transform intra:24.9% inter:36.4%
# [libx264 @ 0x556f4158de00] coded y,uvDC,uvAC intra: 94.8% 0.0% 0.0% inter: 2.4% 0.0% 0.0%
# [libx264 @ 0x556f4158de00] i16 v,h,dc,p: 22% 17% 52%  9%
# [libx264 @ 0x556f4158de00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5% 15% 41%  5%  6%  6%  6%  5%  9%
# [libx264 @ 0x556f4158de00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 23% 20%  6%  7%  6%  9%  5% 10%
# [libx264 @ 0x556f4158de00] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x556f4158de00] Weighted P-Frames: Y:0.8% UV:0.0%
# [libx264 @ 0x556f4158de00] ref P L0: 73.2% 13.4% 12.4%  1.1%  0.0%
# [libx264 @ 0x556f4158de00] ref B L0: 93.5%  6.1%  0.5%
# [libx264 @ 0x556f4158de00] ref B L1: 92.1%  7.9%
# [libx264 @ 0x556f4158de00] kb/s:421.54
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/doom_data/episode_7/%01d.png':
#   Duration: 00:00:01.24, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, gray(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55dd1de1fe00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55dd1de1fe00] profile High, level 3.0
# [libx264 @ 0x55dd1de1fe00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/doom_videos/episode_7.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  543 fps=131 q=-1.0 Lsize=     922kB time=00:00:21.60 bitrate= 349.7kbits/s speed=5.22x
# video:915kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.784754%
# [libx264 @ 0x55dd1de1fe00] frame I:3     Avg QP:16.53  size: 73308
# [libx264 @ 0x55dd1de1fe00] frame P:137   Avg QP:15.54  size:  5144
# [libx264 @ 0x55dd1de1fe00] frame B:403   Avg QP:20.38  size:    28
# [libx264 @ 0x55dd1de1fe00] consecutive B-frames:  0.9%  0.4%  0.0% 98.7%
# [libx264 @ 0x55dd1de1fe00] mb I  I16..4: 12.6% 18.4% 69.0%
# [libx264 @ 0x55dd1de1fe00] mb P  I16..4:  0.1%  0.7%  2.0%  P16..4:  5.9%  2.7%  2.1%  0.0%  0.0%    skip:86.4%
# [libx264 @ 0x55dd1de1fe00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.8%  0.0%  0.0%  direct: 0.0%  skip:99.2%  L0:32.8% L1:66.3% BI: 0.9%
# [libx264 @ 0x55dd1de1fe00] 8x8 transform intra:22.6% inter:38.5%
# [libx264 @ 0x55dd1de1fe00] coded y,uvDC,uvAC intra: 94.7% 0.0% 0.0% inter: 1.9% 0.0% 0.0%
# [libx264 @ 0x55dd1de1fe00] i16 v,h,dc,p: 27% 17% 49%  8%
# [libx264 @ 0x55dd1de1fe00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 13% 45%  5%  6%  5%  5%  4%  8%
# [libx264 @ 0x55dd1de1fe00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 22% 20%  7%  7%  6%  9%  5% 10%
# [libx264 @ 0x55dd1de1fe00] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x55dd1de1fe00] Weighted P-Frames: Y:1.5% UV:0.0%
# [libx264 @ 0x55dd1de1fe00] ref P L0: 70.4% 15.6% 13.1%  1.0%
# [libx264 @ 0x55dd1de1fe00] ref B L0: 93.5%  6.1%  0.3%
# [libx264 @ 0x55dd1de1fe00] ref B L1: 90.9%  9.1%
# [libx264 @ 0x55dd1de1fe00] kb/s:344.77
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/doom_data/episode_8/%01d.png':
#   Duration: 00:00:00.88, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, gray(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5597ace5de00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5597ace5de00] profile High, level 3.0
# [libx264 @ 0x5597ace5de00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/doom_videos/episode_8.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  385 fps=134 q=-1.0 Lsize=     450kB time=00:00:15.28 bitrate= 241.4kbits/s speed=5.32x
# video:445kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.196507%
# [libx264 @ 0x5597ace5de00] frame I:2     Avg QP:16.74  size: 71556
# [libx264 @ 0x5597ace5de00] frame P:97    Avg QP:16.70  size:  3131
# [libx264 @ 0x5597ace5de00] frame B:286   Avg QP:20.34  size:    28
# [libx264 @ 0x5597ace5de00] consecutive B-frames:  0.8%  0.5%  0.0% 98.7%
# [libx264 @ 0x5597ace5de00] mb I  I16..4: 11.4% 21.0% 67.6%
# [libx264 @ 0x5597ace5de00] mb P  I16..4:  0.1%  0.3%  0.9%  P16..4:  8.1%  2.1%  1.6%  0.0%  0.0%    skip:86.9%
# [libx264 @ 0x5597ace5de00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.8%  0.0%  0.0%  direct: 0.0%  skip:99.2%  L0:29.5% L1:70.2% BI: 0.2%
# [libx264 @ 0x5597ace5de00] 8x8 transform intra:22.1% inter:46.3%
# [libx264 @ 0x5597ace5de00] coded y,uvDC,uvAC intra: 94.8% 0.0% 0.0% inter: 2.0% 0.0% 0.0%
# [libx264 @ 0x5597ace5de00] i16 v,h,dc,p: 18% 28% 45%  9%
# [libx264 @ 0x5597ace5de00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7% 17% 48%  4%  5%  5%  4%  3%  6%
# [libx264 @ 0x5597ace5de00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 25% 19%  7%  6%  6%  8%  5%  8%
# [libx264 @ 0x5597ace5de00] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x5597ace5de00] Weighted P-Frames: Y:3.1% UV:0.0%
# [libx264 @ 0x5597ace5de00] ref P L0: 63.9% 16.9% 18.2%  1.0%  0.0%
# [libx264 @ 0x5597ace5de00] ref B L0: 85.2% 14.4%  0.4%
# [libx264 @ 0x5597ace5de00] ref B L1: 92.0%  8.0%
# [libx264 @ 0x5597ace5de00] kb/s:236.30
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/doom_data/episode_4/%01d.png':
#   Duration: 00:00:00.96, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, gray(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55c9cbb9fe00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55c9cbb9fe00] profile High, level 3.0
# [libx264 @ 0x55c9cbb9fe00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/doom_videos/episode_4.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  420 fps=132 q=-1.0 Lsize=     586kB time=00:00:16.68 bitrate= 287.7kbits/s speed=5.24x
# video:580kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.988422%
# [libx264 @ 0x55c9cbb9fe00] frame I:2     Avg QP:17.14  size: 69314
# [libx264 @ 0x55c9cbb9fe00] frame P:106   Avg QP:17.04  size:  4202
# [libx264 @ 0x55c9cbb9fe00] frame B:312   Avg QP:22.68  size:    30
# [libx264 @ 0x55c9cbb9fe00] consecutive B-frames:  1.0%  0.0%  0.0% 99.0%
# [libx264 @ 0x55c9cbb9fe00] mb I  I16..4: 12.0% 21.5% 66.5%
# [libx264 @ 0x55c9cbb9fe00] mb P  I16..4:  0.2%  0.7%  1.7%  P16..4:  6.9%  2.1%  1.6%  0.0%  0.0%    skip:86.8%
# [libx264 @ 0x55c9cbb9fe00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.0%  0.0%  0.0%  direct: 0.0%  skip:99.0%  L0:23.8% L1:75.9% BI: 0.3%
# [libx264 @ 0x55c9cbb9fe00] 8x8 transform intra:24.3% inter:45.1%
# [libx264 @ 0x55c9cbb9fe00] coded y,uvDC,uvAC intra: 94.1% 0.0% 0.0% inter: 1.9% 0.0% 0.0%
# [libx264 @ 0x55c9cbb9fe00] i16 v,h,dc,p: 23% 31% 38%  8%
# [libx264 @ 0x55c9cbb9fe00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6% 18% 42%  5%  6%  6%  6%  4%  7%
# [libx264 @ 0x55c9cbb9fe00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 25% 19%  7%  7%  5%  8%  5%  8%
# [libx264 @ 0x55c9cbb9fe00] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x55c9cbb9fe00] Weighted P-Frames: Y:1.9% UV:0.0%
# [libx264 @ 0x55c9cbb9fe00] ref P L0: 63.1% 17.0% 18.6%  1.3%
# [libx264 @ 0x55c9cbb9fe00] ref B L0: 89.8%  9.7%  0.5%
# [libx264 @ 0x55c9cbb9fe00] ref B L1: 85.7% 14.3%
# [libx264 @ 0x55c9cbb9fe00] kb/s:282.52
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/doom_data/episode_0/%01d.png':
#   Duration: 00:00:01.08, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, gray(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f6a2f29e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55f6a2f29e00] profile High, level 3.0
# [libx264 @ 0x55f6a2f29e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/doom_videos/episode_0.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  473 fps=120 q=-1.0 Lsize=     897kB time=00:00:18.80 bitrate= 390.7kbits/s speed=4.78x
# video:890kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.713813%
# [libx264 @ 0x55f6a2f29e00] frame I:2     Avg QP:17.19  size: 68706
# [libx264 @ 0x55f6a2f29e00] frame P:118   Avg QP:16.78  size:  6459
# [libx264 @ 0x55f6a2f29e00] frame B:353   Avg QP:25.21  size:    32
# [libx264 @ 0x55f6a2f29e00] consecutive B-frames:  0.4%  0.0%  0.6% 98.9%
# [libx264 @ 0x55f6a2f29e00] mb I  I16..4: 11.5% 27.5% 60.9%
# [libx264 @ 0x55f6a2f29e00] mb P  I16..4:  0.2%  1.5%  3.4%  P16..4:  6.1%  2.5%  2.0%  0.0%  0.0%    skip:84.3%
# [libx264 @ 0x55f6a2f29e00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.2%  0.0%  0.0%  direct: 0.0%  skip:98.8%  L0:28.1% L1:71.4% BI: 0.5%
# [libx264 @ 0x55f6a2f29e00] 8x8 transform intra:29.7% inter:39.9%
# [libx264 @ 0x55f6a2f29e00] coded y,uvDC,uvAC intra: 94.6% 0.0% 0.0% inter: 1.8% 0.0% 0.0%
# [libx264 @ 0x55f6a2f29e00] i16 v,h,dc,p: 32% 13% 46%  8%
# [libx264 @ 0x55f6a2f29e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6% 14% 38%  6%  7%  7%  7%  5%  9%
# [libx264 @ 0x55f6a2f29e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 22% 19%  7%  7%  6% 10%  5% 10%
# [libx264 @ 0x55f6a2f29e00] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x55f6a2f29e00] Weighted P-Frames: Y:1.7% UV:0.0%
# [libx264 @ 0x55f6a2f29e00] ref P L0: 67.8% 16.0% 15.0%  1.3%
# [libx264 @ 0x55f6a2f29e00] ref B L0: 90.8%  8.0%  1.2%
# [libx264 @ 0x55f6a2f29e00] ref B L1: 87.4% 12.6%
# [libx264 @ 0x55f6a2f29e00] kb/s:385.16
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/doom_data/episode_6/%01d.png':
#   Duration: 00:00:01.16, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, gray(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ca80a43e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55ca80a43e00] profile High, level 3.0
# [libx264 @ 0x55ca80a43e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/doom_videos/episode_6.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  508 fps=129 q=-1.0 Lsize=     770kB time=00:00:20.20 bitrate= 312.4kbits/s speed=5.11x
# video:764kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.884281%
# [libx264 @ 0x55ca80a43e00] frame I:3     Avg QP:17.73  size: 68199
# [libx264 @ 0x55ca80a43e00] frame P:128   Avg QP:17.18  size:  4414
# [libx264 @ 0x55ca80a43e00] frame B:377   Avg QP:23.62  size:    31
# [libx264 @ 0x55ca80a43e00] consecutive B-frames:  1.0%  0.0%  0.6% 98.4%
# [libx264 @ 0x55ca80a43e00] mb I  I16..4: 11.4% 23.5% 65.1%
# [libx264 @ 0x55ca80a43e00] mb P  I16..4:  0.2%  0.6%  1.8%  P16..4:  7.3%  2.4%  1.7%  0.0%  0.0%    skip:86.0%
# [libx264 @ 0x55ca80a43e00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.2%  0.0%  0.0%  direct: 0.0%  skip:98.8%  L0:27.6% L1:72.2% BI: 0.3%
# [libx264 @ 0x55ca80a43e00] 8x8 transform intra:23.6% inter:42.2%
# [libx264 @ 0x55ca80a43e00] coded y,uvDC,uvAC intra: 94.6% 0.0% 0.0% inter: 2.0% 0.0% 0.0%
# [libx264 @ 0x55ca80a43e00] i16 v,h,dc,p: 19% 30% 42%  9%
# [libx264 @ 0x55ca80a43e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6% 18% 41%  5%  6%  7%  6%  5%  7%
# [libx264 @ 0x55ca80a43e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 27% 18%  6%  7%  5%  8%  5%  8%
# [libx264 @ 0x55ca80a43e00] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x55ca80a43e00] Weighted P-Frames: Y:1.6% UV:0.0%
# [libx264 @ 0x55ca80a43e00] ref P L0: 68.1% 14.8% 16.0%  1.1%
# [libx264 @ 0x55ca80a43e00] ref B L0: 85.8% 13.9%  0.4%
# [libx264 @ 0x55ca80a43e00] ref B L1: 85.0% 15.0%
# [libx264 @ 0x55ca80a43e00] kb/s:307.60
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/doom_data/episode_1/%01d.png':
#   Duration: 00:00:01.36, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, gray(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x564fd7ed1e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x564fd7ed1e00] profile High, level 3.0
# [libx264 @ 0x564fd7ed1e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/doom_videos/episode_1.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  595 fps=131 q=-1.0 Lsize=     798kB time=00:00:23.68 bitrate= 275.9kbits/s speed=5.23x
# video:790kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.985192%
# [libx264 @ 0x564fd7ed1e00] frame I:3     Avg QP:17.03  size: 70345
# [libx264 @ 0x564fd7ed1e00] frame P:150   Avg QP:16.63  size:  3890
# [libx264 @ 0x564fd7ed1e00] frame B:442   Avg QP:20.34  size:    31
# [libx264 @ 0x564fd7ed1e00] consecutive B-frames:  0.8%  0.3%  0.0% 98.8%
# [libx264 @ 0x564fd7ed1e00] mb I  I16..4: 12.9% 28.5% 58.6%
# [libx264 @ 0x564fd7ed1e00] mb P  I16..4:  0.1%  0.5%  1.6%  P16..4:  8.3%  2.1%  1.8%  0.0%  0.0%    skip:85.7%
# [libx264 @ 0x564fd7ed1e00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.1%  0.0%  0.0%  direct: 0.0%  skip:98.9%  L0:24.7% L1:74.8% BI: 0.5%
# [libx264 @ 0x564fd7ed1e00] 8x8 transform intra:25.7% inter:45.6%
# [libx264 @ 0x564fd7ed1e00] coded y,uvDC,uvAC intra: 93.9% 0.0% 0.0% inter: 2.0% 0.0% 0.0%
# [libx264 @ 0x564fd7ed1e00] i16 v,h,dc,p: 16% 23% 53%  8%
# [libx264 @ 0x564fd7ed1e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7% 15% 44%  5%  6%  6%  6%  5%  7%
# [libx264 @ 0x564fd7ed1e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 26% 19%  6%  6%  5%  8%  4%  8%
# [libx264 @ 0x564fd7ed1e00] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x564fd7ed1e00] Weighted P-Frames: Y:3.3% UV:0.0%
# [libx264 @ 0x564fd7ed1e00] ref P L0: 63.5% 16.1% 19.3%  1.0%
# [libx264 @ 0x564fd7ed1e00] ref B L0: 87.6% 12.0%  0.4%
# [libx264 @ 0x564fd7ed1e00] ref B L1: 93.5%  6.5%
# [libx264 @ 0x564fd7ed1e00] kb/s:271.59
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/doom_data/episode_5/%01d.png':
#   Duration: 00:00:01.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, gray(pc), 640x480, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ece341de00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55ece341de00] profile High, level 3.0
# [libx264 @ 0x55ece341de00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/doom_videos/episode_5.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 640x480, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  438 fps=127 q=-1.0 Lsize=     750kB time=00:00:17.40 bitrate= 352.9kbits/s speed=5.04x
# video:744kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.800505%
# [libx264 @ 0x55ece341de00] frame I:2     Avg QP:16.70  size: 69945
# [libx264 @ 0x55ece341de00] frame P:109   Avg QP:16.11  size:  5604
# [libx264 @ 0x55ece341de00] frame B:327   Avg QP:21.29  size:    30
# [libx264 @ 0x55ece341de00] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x55ece341de00] mb I  I16..4: 11.1% 20.2% 68.8%
# [libx264 @ 0x55ece341de00] mb P  I16..4:  0.2%  1.2%  2.8%  P16..4:  6.4%  2.6%  2.0%  0.0%  0.0%    skip:84.8%
# [libx264 @ 0x55ece341de00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.1%  0.0%  0.0%  direct: 0.0%  skip:98.9%  L0:29.1% L1:70.2% BI: 0.8%
# [libx264 @ 0x55ece341de00] 8x8 transform intra:25.6% inter:41.9%
# [libx264 @ 0x55ece341de00] coded y,uvDC,uvAC intra: 94.1% 0.0% 0.0% inter: 1.9% 0.0% 0.0%
# [libx264 @ 0x55ece341de00] i16 v,h,dc,p: 26% 23% 42%  9%
# [libx264 @ 0x55ece341de00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7% 16% 41%  5%  6%  6%  6%  5%  8%
# [libx264 @ 0x55ece341de00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 25% 19%  6%  7%  5%  9%  5%  9%
# [libx264 @ 0x55ece341de00] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x55ece341de00] Weighted P-Frames: Y:1.8% UV:0.0%
# [libx264 @ 0x55ece341de00] ref P L0: 67.1% 15.7% 16.0%  1.2%
# [libx264 @ 0x55ece341de00] ref B L0: 93.1%  6.7%  0.2%
# [libx264 @ 0x55ece341de00] ref B L1: 91.7%  8.3%
# [libx264 @ 0x55ece341de00] kb/s:347.35

# %%
#import numpy as np
#import glob
#import matplotlib.pyplot as plt
#import skimage.io
#import skimage.color
#import skimage.filters
#
## blur the image to denoise
#blurred_image = skimage.filters.gaussian(episodes_images[0][0], sigma=1.0)
#
#fig, ax = plt.subplots()
#plt.imshow(blurred_image, cmap='gray')
#plt.show()
#
#histogram, bin_edges = np.histogram(blurred_image, bins=256, range=(0.0, 1.0))
#
#plt.plot(bin_edges[0:-1], histogram)
#plt.title("Grayscale Histogram")
#plt.xlabel("grayscale value")
#plt.ylabel("pixels")
#plt.xlim(0, 1.0)
#plt.show()
#
## perform automatic thresholding to produce a binary image
#t = skimage.filters.threshold_otsu(blurred_image)
#binary_mask = blurred_image > t
#
#fig, ax = plt.subplots()
#plt.imshow(binary_mask, cmap='gray')
#plt.show()
#

# %%
#import matplotlib.pyplot as plt
#
#for data_index , frames  in enumerate(episodes_images):
#  for idx , image in enumerate(frames):
#    plt.imshow(image)
#    plt.show()
